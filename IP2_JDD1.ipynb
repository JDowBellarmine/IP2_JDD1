# %%
import pandas as pd
df = pd.read_csv('weather_2012.csv')

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
df.sample(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 3784  2012-06-06 16:00:00      21.3                 8.2           43
# 386   2012-01-17 02:00:00      -9.7               -13.7           73
# 742   2012-01-31 22:00:00      -7.1               -10.4           77
# 1384  2012-02-27 16:00:00      -4.9                -7.9           79
# 6123  2012-09-12 03:00:00      13.2                 9.9           80
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 3784               13             48.3           100.90  Mostly Cloudy
# 386                 9             25.0           100.84         Cloudy
# 742                19              9.7           100.95           Snow
# 1384               19             19.3           101.13           Snow
# 6123                4             25.0           101.90          Clear

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
col_names1=['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
       'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather']

# %%
col_names=['date_time', 'temp_c', 'dew_point', 'relative_humidity', 'wind_speed', 'visibility', 'pressure', 'weather']

# %%
df.columns=col_names

# %%
df.columns
# Out:
# Index(['date_time', 'temp_c', 'dew_point', 'relative_humidity', 'wind_speed',
#        'visibility', 'pressure', 'weather'],
#       dtype='object')

# %%
df.mean()
# Out:
# temp_c                 8.798144
# dew_point              2.555294
# relative_humidity     67.431694
# wind_speed            14.945469
# visibility            27.664447
# pressure             101.051623
# dtype: float64

# %%
df.median
# Out:
# <bound method DataFrame.median of                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
# ...

# %%
df.mode()
# Out:
#                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    16.6       -0.9               68.0         9.0
# 1     2012-01-01 01:00:00     NaN       12.9                NaN         NaN
# 2     2012-01-01 02:00:00     NaN        NaN                NaN         NaN
# 3     2012-01-01 03:00:00     NaN        NaN                NaN         NaN
# 4     2012-01-01 04:00:00     NaN        NaN                NaN         NaN
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     NaN        NaN                NaN         NaN
# 8780  2012-12-31 20:00:00     NaN        NaN                NaN         NaN
# 8781  2012-12-31 21:00:00     NaN        NaN                NaN         NaN
# 8782  2012-12-31 22:00:00     NaN        NaN                NaN         NaN
# 8783  2012-12-31 23:00:00     NaN        NaN                NaN         NaN
#
#       visibility  pressure       weather
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
# ...

# %%
df['temp_f'] = df.apply(lambda x: (9/5)*x['temp_c']+32,axis=1)
print(df)
# Out:
#                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather  temp_f
# ...

# %%
df=df[['date_time','temp_f','temp_c','dew_point','relative_humidity','wind_speed','visibility','pressure','weather']]

# %%
df.head()
# Out:
#              date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0  2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1  2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2  2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3  2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4  2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
#
#    wind_speed  visibility  pressure               weather
# 0           4         8.0    101.24                   Fog
# 1           4         8.0    101.24                   Fog
# 2           7         4.0    101.26  Freezing Drizzle,Fog
# 3           6         4.0    101.27  Freezing Drizzle,Fog
# 4           7         4.8    101.23                   Fog

# %%
df.dtypes
# Out:
# date_time             object
# temp_f               float64
# temp_c               float64
# dew_point            float64
# relative_humidity      int64
# wind_speed             int64
# visibility           float64
# pressure             float64
# weather               object
# dtype: object

# %%
df.date_time = pd.to_datetime(df.date_time)

# %%
df.dtypes
# Out:
# date_time            datetime64[ns]
# temp_f                      float64
# temp_c                      float64
# dew_point                   float64
# relative_humidity             int64
# wind_speed                    int64
# visibility                  float64
# pressure                    float64
# weather                      object
# dtype: object

# %%
df.head()
# Out:
#             date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0 2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1 2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2 2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3 2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4 2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
#
#    wind_speed  visibility  pressure               weather
# 0           4         8.0    101.24                   Fog
# 1           4         8.0    101.24                   Fog
# 2           7         4.0    101.26  Freezing Drizzle,Fog
# 3           6         4.0    101.27  Freezing Drizzle,Fog
# 4           7         4.8    101.23                   Fog

# %%
monthly_avg = df['temp_f'].groupby(df.date_time.dt.month).mean()

# %%
df1=monthly_avg.to_frame()

# %%
df1=df1.reset_index()

# %%
df1=df1.rename(columns = {'index':'','date_time':'month','temp_f':'temp_f'})

# %%
df1
# Out:
#     month     temp_f
# 0       1  18.731290
# 1       2  24.395000
# 2       3  37.618226
# 3       4  44.616750
# 4       5  61.227984
# 5       6  68.241250
# 6       7  73.022097
# 7       8  72.102742
# 8       9  61.672000
# 9      10  51.718952
# 10     11  33.676500
# 11     12  26.048629

# %%
df1['month'] = df1['month'].apply(str)

# %%
df1.at[0,'month']='January'
df1.at[1,'month']='Febuary'
df1.at[2,'month']='March'
df1.at[3,'month']='April'
df1.at[4,'month']='May'
df1.at[5,'month']='June'
df1.at[6,'month']='July'
df1.at[7,'month']='August'
df1.at[8,'month']='September'
df1.at[9,'month']='October'
df1.at[10,'month']='November'
df1.at[11,'month']='December'

# %%
df1
# Out:
#         month     temp_f
# 0     January  18.731290
# 1     Febuary  24.395000
# 2       March  37.618226
# 3       April  44.616750
# 4         May  61.227984
# 5        June  68.241250
# 6        July  73.022097
# 7      August  72.102742
# 8   September  61.672000
# 9     October  51.718952
# 10   November  33.676500
# 11   December  26.048629

# %%
hourly_avg = df['temp_f'].groupby(df.date_time.dt.hour).mean()

# %%
hourly_avg.index.name='Hour'

# %%
hourly_avg
# Out:
# Hour
# 0     45.623443
# 1     44.762787
# 2     43.980820
# 3     43.325246
# 4     42.744426
# 5     42.291967
# 6     42.859508
# 7     43.831311
# 8     45.280656
# 9     46.987213
# 10    48.699672
# 11    50.193770
# 12    51.541803
# 13    52.508689
# 14    53.196721
# 15    53.391475
# 16    53.178033
# 17    52.297705
# 18    51.181311
# 19    50.041311
# 20    48.848197
# 21    47.851803
# 22    47.064918
# 23    46.397049
# Name: temp_f, dtype: float64

# %%
hourly_avg.index=['12:00AM','1:00AM','2:00AM','3:00AM','4:00AM','5:00AM','6:00AM','7:00AM','8:00AM','9:00AM','10:00AM','11:00AM','12:00PM','1:00PM','2:00PM','3:00PM','4:00PM','5:00PM','6:00PM','7:00PM','8:00PM','9:00PM','10:00PM','11:00PM']

# %%
hourly_avg
# Out:
# 12:00AM    45.623443
# 1:00AM     44.762787
# 2:00AM     43.980820
# 3:00AM     43.325246
# 4:00AM     42.744426
# 5:00AM     42.291967
# 6:00AM     42.859508
# 7:00AM     43.831311
# 8:00AM     45.280656
# 9:00AM     46.987213
# 10:00AM    48.699672
# 11:00AM    50.193770
# 12:00PM    51.541803
# 1:00PM     52.508689
# 2:00PM     53.196721
# 3:00PM     53.391475
# 4:00PM     53.178033
# 5:00PM     52.297705
# 6:00PM     51.181311
# 7:00PM     50.041311
# 8:00PM     48.848197
# 9:00PM     47.851803
# 10:00PM    47.064918
# 11:00PM    46.397049
# Name: temp_f, dtype: float64

# %%
df
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0    2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1    2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2    2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3    2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4    2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
# ...                  ...     ...     ...        ...                ...
# 8779 2012-12-31 19:00:00   32.18     0.1       -2.7                 81
# 8780 2012-12-31 20:00:00   32.36     0.2       -2.4                 83
# 8781 2012-12-31 21:00:00   31.10    -0.5       -1.5                 93
# 8782 2012-12-31 22:00:00   31.64    -0.2       -1.8                 89
# 8783 2012-12-31 23:00:00   32.00     0.0       -2.1                 86
#
#       wind_speed  visibility  pressure               weather
# ...

# %%
df['weather'].groupby(df['weather']).count()
# Out:
# weather
# Clear                                      1326
# Cloudy                                     1728
# Drizzle                                      41
# Drizzle,Fog                                  80
# Drizzle,Ice Pellets,Fog                       1
# Drizzle,Snow                                  2
# Drizzle,Snow,Fog                             15
# Fog                                         150
# Freezing Drizzle                              7
# Freezing Drizzle,Fog                          6
# Freezing Drizzle,Haze                         3
# Freezing Drizzle,Snow                        11
# Freezing Fog                                  4
# Freezing Rain                                14
# Freezing Rain,Fog                             4
# Freezing Rain,Haze                            2
# Freezing Rain,Ice Pellets,Fog                 1
# Freezing Rain,Snow Grains                     1
# Haze                                         16
# ...

# %%
list1=['Clear',
 'Cloudy',
 'Drizzle',
 'Drizzle','Fog',
 'Drizzle','Ice Pellets','Fog',
 'Drizzle','Snow',
 'Drizzle','Snow','Fog',
 'Fog',
 'Freezing Drizzle',
 'Freezing Drizzle','Fog',
 'Freezing Drizzle','Haze',
 'Freezing Drizzle','Snow',
 'Freezing Fog',
 'Freezing Rain',
 'Freezing Rain','Fog',
 'Freezing Rain','Haze',
 'Freezing Rain','Ice Pellets','Fog',
 'Freezing Rain','Snow Grains',
 'Haze',
 'Mainly Clear',
 'Moderate Rain','Fog',
 'Moderate Snow',
 'Moderate Snow','Blowing Snow',
 'Mostly Cloudy',
 'Rain',
 'Rain Showers',
 'Rain Showers','Fog',
 'Rain Showers','Snow Showers',
 'Rain','Fog',
 'Rain','Haze',
 'Rain','Ice Pellets',
 'Rain','Snow',
 'Rain','Snow Grains',
 'Rain','Snow','Fog',
 'Rain','Snow','Ice Pellets',
 'Snow',
 'Snow Pellets',
 'Snow Showers',
 'Snow Showers','Fog',
 'Snow','Blowing Snow',
 'Snow','Fog',
 'Snow','Haze',
 'Snow','Ice Pellets',
 'Thunderstorms',
 'Thunderstorms','Heavy Rain Showers',
 'Thunderstorms','Moderate Rain Showers','Fog',
 'Thunderstorms','Rain',
 'Thunderstorms','Rain Showers',
 'Thunderstorms','Rain Showers','Fog',
 'Thunderstorms','Rain','Fog']

# %%
set1=set(list1)

# %%
set1
# Out:
# {'Blowing Snow',
#  'Clear',
#  'Cloudy',
#  'Drizzle',
#  'Fog',
#  'Freezing Drizzle',
#  'Freezing Fog',
#  'Freezing Rain',
#  'Haze',
#  'Heavy Rain Showers',
#  'Ice Pellets',
#  'Mainly Clear',
#  'Moderate Rain',
#  'Moderate Rain Showers',
#  'Moderate Snow',
#  'Mostly Cloudy',
#  'Rain',
#  'Rain Showers',
#  'Snow',
#  'Snow Grains',
#  'Snow Pellets',
#  'Snow Showers',
#  'Thunderstorms'}

# %%
sorted(set1)
# Out:
# ['Blowing Snow',
#  'Clear',
#  'Cloudy',
#  'Drizzle',
#  'Fog',
#  'Freezing Drizzle',
#  'Freezing Fog',
#  'Freezing Rain',
#  'Haze',
#  'Heavy Rain Showers',
#  'Ice Pellets',
#  'Mainly Clear',
#  'Moderate Rain',
#  'Moderate Rain Showers',
#  'Moderate Snow',
#  'Mostly Cloudy',
#  'Rain',
#  'Rain Showers',
#  'Snow',
#  'Snow Grains',
#  'Snow Pellets',
#  'Snow Showers',
#  'Thunderstorms']

# %%
col_names2=['Date/Time','Temp (F)', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
       'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather']

# %%
df.columns=col_names2

# %%
df
# Out:
#                Date/Time  Temp (F)  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0    2012-01-01 00:00:00     28.76      -1.8                -3.9           86
# 1    2012-01-01 01:00:00     28.76      -1.8                -3.7           87
# 2    2012-01-01 02:00:00     28.76      -1.8                -3.4           89
# 3    2012-01-01 03:00:00     29.30      -1.5                -3.2           88
# 4    2012-01-01 04:00:00     29.30      -1.5                -3.3           88
# ...                  ...       ...       ...                 ...          ...
# 8779 2012-12-31 19:00:00     32.18       0.1                -2.7           81
# 8780 2012-12-31 20:00:00     32.36       0.2                -2.4           83
# 8781 2012-12-31 21:00:00     31.10      -0.5                -1.5           93
# 8782 2012-12-31 22:00:00     31.64      -0.2                -1.8           89
# 8783 2012-12-31 23:00:00     32.00       0.0                -2.1           86
#
# ...

# %%
df.to_csv('weather_2012_new.csv',index=False)

# %%
monthly_avg.to_csv('monthly_avg.csv')

# %%
hourly_avg.to_csv('hourly_avg.csv')
